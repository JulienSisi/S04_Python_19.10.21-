# %% [markdown]
# # 2.0. Set up Librairies

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # 2.1. Télécharger les fichiers csv et l'ouvrir sur ton notebook

# %% [markdown]
# ## Fichier : cwurData.csv

# %%
data1 = pd.read_csv('/Users/juliensisavath2017/THP_loc/THP-2/S04/2/Project/2.Tour_de_France_des_universites/archive/cwurData.csv', encoding='utf-8', sep=",")
df1 = pd.DataFrame(data1)
df1.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %% [markdown]
# ## Fichier : educational_attainment_supplementary_data.csv

# %%
data2 = pd.read_csv("/Users/juliensisavath2017/THP_loc/THP-2/S04/2/Project/2.Tour_de_France_des_universites/archive/educational_attainment_supplementary_data.csv", encoding='latin-1', sep=",")
df2 = pd.DataFrame(data2)
df2.head()
# Out:
#   country_name                                        series_name  1985  1986  \
# 0  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33   NaN
# 1  Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03   NaN
# 2  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83   NaN
# 3  Afghanistan  Barro-Lee: Average years of primary schooling,...  2.34   NaN
# 4  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.54   NaN
#
#    1987  1990  1991  1992  1993  1995  ...  2005  2006  2007  2008  2009  \
# 0   NaN  0.44   NaN   NaN   NaN  0.57  ...  0.86   NaN   NaN   NaN   NaN
# 1   NaN  1.26   NaN   NaN   NaN  1.54  ...  2.18   NaN   NaN   NaN   NaN
# 2   NaN  0.95   NaN   NaN   NaN  1.26  ...  1.01   NaN   NaN   NaN   NaN
# 3   NaN  2.22   NaN   NaN   NaN  2.37  ...  2.26   NaN   NaN   NaN   NaN
# 4   NaN  0.92   NaN   NaN   NaN  0.94  ...  2.00   NaN   NaN   NaN   NaN
#
#    2010  2011  2012  2013  2015
# ...

# %% [markdown]
# ## Fichier : school_and_country_table.csv

# %%
data3 = pd.read_csv("/Users/juliensisavath2017/THP_loc/THP-2/S04/2/Project/2.Tour_de_France_des_universites/archive/school_and_country_table.csv", encoding='latin-1', sep=",")
df3 = pd.DataFrame(data3)
df3.head()
# Out:
#                              school_name                   country
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America

# %% [markdown]
# ## Fichier : shanghaiData.csv

# %%
data4 = pd.read_csv("/Users/juliensisavath2017/THP_loc/THP-2/S04/2/Project/2.Tour_de_France_des_universites/archive/shanghaiData.csv", encoding='latin-1', sep=",")
df4 = pd.DataFrame(data4)
df4.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %% [markdown]
# ## Fichier : shanghaiData.csv (bis)

# %%
data6 = pd.read_csv("/Users/juliensisavath2017/THP_loc/THP-2/S04/2/Project/2.Tour_de_France_des_universites/archive/shanghaiData.csv", encoding='latin-1', sep=",", engine = "python")
df6 = pd.DataFrame(data6)
df6.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %% [markdown]
# ## Fichier timesData.csv

# %%
data5 = pd.read_csv("/Users/juliensisavath2017/THP_loc/THP-2/S04/2/Project/2.Tour_de_France_des_universites/archive/timesData.csv", encoding='latin-1', sep=",")
df5 = pd.DataFrame(data5)
df5.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %% [markdown]
# # 2.2. Répondre aux questions posées par ton manager

# %% [markdown]
# ## 2.2.1. Donne un aperçu de chaque fichier csv et décris en une phrase son contenu.

# %% [markdown]
# ## 2.2.2. Quelles années sont prises en charge par chaque classement ?

# %%
df1.year.unique()
# Out:
# array([2012, 2013, 2014, 2015])

# %% [markdown]
# ### Réponse : df1 de 2012 à 2015

# %%
df4.year.unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015])

# %% [markdown]
# ### Réponse : df4 de 2005 à 2015

# %%
df5.year.unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016])

# %% [markdown]
# ### Réponse : df5 de 2011 à 2016

# %%
df6.year.unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015])

# %% [markdown]
# ### Réponse : df6 de 2005 à 2015

# %% [markdown]
# ## 2.2.3. Combien d'universités sont prises en compte annuellement par chaque classement en moyenne ? Il s'agit ici de donner le nombre moyen d'universités prises en compte par chaque classement lors d'une année.

# %%
print(
    'DF1 :', df1['year'].value_counts().mean(),
    'DF4 :', df4['year'].value_counts().mean(),
    'DF5 :', df5['year'].value_counts().mean(), 
    'DF6 :', df6['year'].value_counts().mean()
)
# Out:
# DF1 : 550.0 DF4 : 445.1818181818182 DF5 : 433.8333333333333 DF6 : 445.1818181818182

# %% [markdown]
# ### Réponse DF1 : 550 DF4 : 445.2 DF5 : 433.8 DF6 : 445.2

# %% [markdown]
# ## 2.2.4. Quels sont les rankings obtenus par l'Université de Strabourg dans chacun des 3 classements disponibles ?

# %%
df_strasbourg = pd.concat([df5, df4, df6])
cond_ = (df_strasbourg["university_name"].str.contains("University of Strasbourg", na=False))
df_strasbourg.loc[cond_,:][['world_rank','university_name', 'year']]
# Out:
#      world_rank           university_name  year
# 422     201-225  University of Strasbourg  2012
# 825     201-225  University of Strasbourg  2013
# 1223    201-225  University of Strasbourg  2014
# 1619    201-225  University of Strasbourg  2015
# 2142    301-350  University of Strasbourg  2016
# 91           92  University of Strasbourg  2005
# 595          96  University of Strasbourg  2006
# 1100         99  University of Strasbourg  2007
# 1656    101-151  University of Strasbourg  2008
# 2158    101-151  University of Strasbourg  2009
# 2657    101-150  University of Strasbourg  2010
# 3157    102-150  University of Strasbourg  2011
# 3659    101-150  University of Strasbourg  2012
# 3894         97  University of Strasbourg  2013
# 3991         95  University of Strasbourg  2014
# 4485         87  University of Strasbourg  2015
# 91           92  University of Strasbourg  2005
# 595          96  University of Strasbourg  2006
# 1100         99  University of Strasbourg  2007
# ...

# %% [markdown]
# ### Réponse : Tableau ci-contre

# %% [markdown]
# ## 2.2.5. Selon le classement du Times, quels sont les 20 meilleures universités en 2016 ? Quelle est la part d'universités américaines ?

# %%
df_result = df5.loc[df5['year'] == 2016].head(20)
df_result
# Out:
#      world_rank                                    university_name  \
# 1803          1                 California Institute of Technology
# 1804          2                               University of Oxford
# 1805          3                                Stanford University
# 1806          4                            University of Cambridge
# 1807          5              Massachusetts Institute of Technology
# 1808          6                                 Harvard University
# 1809          7                               Princeton University
# 1810          8                            Imperial College London
# 1811          9  ETH Zurich â Swiss Federal Institute of Tech...
# 1812         10                              University of Chicago
# 1813         11                           Johns Hopkins University
# 1814         12                                    Yale University
# 1815         13                 University of California, Berkeley
# ...

# %%
(df_result['country'] == "United States of America").value_counts()
# Out:
# True     14
# False     6
# Name: country, dtype: int64

# %%
len(df_result['country'] == "United States of America")
# Out:
# 20

# %% [markdown]
# ### Réponse : il y a le tableau et 14 universités Américaines

# %% [markdown]
# ## 2.2.6. Combien chaque pays possède d'universités dans le classement de Shanghai en 2015 ? Range la liste par ordre décroissant. Pense à t'aider de la table université - pays pour réaliser cette requête.

# %%
df_merged = pd.merge(df6, df3, left_on="university_name", right_on="school_name")
df_merged = df_merged.loc[df_merged['year'] == 2015]

df_merged['country'].value_counts().sort_values(ascending=True)
# Out:
# Serbia                       1
# New Zealand                  1
# Turkey                       1
# India                        1
# Chile                        1
# Slovenia                     1
# Hungary                      1
# Russian Federation           1
# Egypt                        1
# Czech Republic               1
# Hong Kong                    1
# Mexico                       1
# Greece                       2
# Iran                         2
# Norway                       2
# Saudi Arabia                 2
# Singapore                    2
# Poland                       2
# Belgium                      3
# Brazil                       3
# Israel                       3
# Portugal                     3
# Republic of Ireland          3
# South Africa                 4
# Switzerland                  5
# France                       5
# Denmark                      5
# Finland                      5
# Austria                      5
# Taiwan                       6
# ...

# %%
df_merged = pd.merge(df6, df3, left_on="university_name", right_on="school_name")
df_merged
# Out:
#      world_rank                      university_name national_rank  \
# 0             1                   Harvard University             1
# 1             1                   Harvard University             1
# 2             1                   Harvard University             1
# 3             1                   Harvard University             1
# 4             1                   Harvard University             1
# ...         ...                                  ...           ...
# 3009    401-500           Capital Medical University         28-32
# 3010    401-500  Queensland University of Technology            20
# 3011    401-500      Sharif University of Technology             2
# 3012    401-500                  University of Genoa         11-20
# 3013    401-500                University of Seville          9-13
#
#       total_score  alumni  award   hici     ns    pub   pcp  year  \
# 0           100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# ...

# %% [markdown]
# ## 2.2.7. Quelles sont les universités françaises présentes dans le classement du Center for WUR ?

# %%
df1.loc[df1["country"] == 'France'].institution.unique()
# Out:
# array(['University of Paris-Sud', 'École normale supérieure - Paris',
#        'École Polytechnique', 'Pierre-and-Marie-Curie University',
#        'Mines ParisTech', 'Paris Diderot University - Paris 7',
#        'University of Strasbourg', 'Joseph Fourier University',
#        'Aix-Marseille University', 'Claude Bernard University Lyon 1',
#        'University of Montpellier 2',
#        'Paul Sabatier University - Toulouse III',
#        'Paris Descartes University', 'University of Lorraine',
#        'University of Bordeaux II',
#        'Versailles Saint-Quentin-en-Yvelines University',
#        'University of Bordeaux I', 'École normale supérieure de Lyon',
#        'University of Rennes 1', 'Grenoble Institute of Technology',
#        'École Centrale Paris', 'University of Montpellier 1',
#        'University of Nice Sophia Antipolis', 'University of Savoy',
#        'University of Nantes',
#        'University Lille 1: Sciences and Technologies',
# ...

# %% [markdown]
# ## 2.2.8. Quels pays ont les plus faibles ratios (Dépenses dans les Institutions du Supérieur (Privées et Publiques) en 2011) / Nombre d'universités dans le classement du Times en 2011 ? Range cette liste par ordre croissant.

# %% [markdown]
# # 2.3. Trouver des informations intéressantes

# %% [markdown]
# ## Recherche n°1 : Les 20 meilleures universités au classement du Times ont un taux de parité relativement peu élevé (30% vs 45% en moyenne)

# %% [markdown]
# ## Recherche n°2 : L'université de Strasbourg fait partie du 10% des universités présentes dans le classement qui ont le moins d'étudiants internationaux

# %% [markdown]
# ## Recherche n°3 :

# %% [markdown]
# ## Recherche n°4 :

# %% [markdown]
# ## Recherche n°5 :

# %% [markdown]
# ## Recherche n°6 :
